# %% [markdown]
# # Phase 2 Model
# Автоматически сгенерированный ноутбук для воспроизведения результатов.
# Ключевые фигуры сохраняются в `notebooks/figures`.

# %%
import pickle
from pathlib import Path
import pandas as pd

with open('../data/btc_processed_data.pkl', 'rb') as f:
    pkg = pickle.load(f)
list(pkg.keys())

# %% [markdown]
# ## Фигуры
# - `figures/phase2_01_features_target_1d.png`
# - `figures/phase2_02_model_quality.png`
# - `figures/phase2_03_trading.png`
# - `figures/phase2_04_compare_models.png`
# - `figures/phase2_05_test_results.png`
